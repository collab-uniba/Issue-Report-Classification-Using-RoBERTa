# %%
# !python3 --version
# Out:
# Python 3.8.0

# %%
# !nvidia-smi
# Out:
# Mon Oct 17 18:08:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.29.05    Driver Version: 495.29.05    CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-PCI...  Off  | 00000000:25:00.0 Off |                    0 |
# | N/A   25C    P0    33W / 250W |  25881MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     34524      C   /usr/bin/python3                18247MiB |
# |    0   N/A  N/A    160443      C   /usr/bin/python3                 7631MiB |
# +-----------------------------------------------------------------------------+

# %%
# !python -m pip install ekphrasis
# !python -m pip install transformers
# !python -m pip install imblearn
# !python -m pip install pandas
# !python -m pip install sklearn
# !python -m pip install numpy
# !python -m pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install textattack
# !python -m pip install transformers
# !python -m pip install ipywidgets==7.4.2
# !python -m pip install mlflow
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ekphrasis in /home/novielli/.local/lib/python3.8/site-packages (0.5.4)
# Requirement already satisfied: ujson in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (5.4.0)
# Requirement already satisfied: matplotlib in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (3.5.2)
# Requirement already satisfied: ftfy in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (6.1.1)
# Requirement already satisfied: colorama in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (0.4.5)
# Requirement already satisfied: numpy in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (1.23.1)
# Requirement already satisfied: tqdm in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: nltk in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: termcolor in /home/novielli/.local/lib/python3.8/site-packages (from ekphrasis) (1.1.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/novielli/.local/lib/python3.8/site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: cycler>=0.10 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/novielli/.local/lib/python3.8/site-packages (from nltk->ekphrasis) (2022.7.9)
# Requirement already satisfied: click in /home/novielli/.local/lib/python3.8/site-packages (from nltk->ekphrasis) (8.0.4)
# Requirement already satisfied: joblib in /home/novielli/.local/lib/python3.8/site-packages (from nltk->ekphrasis) (1.1.0)
# Requirement already satisfied: six>=1.5 in /home/novielli/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/novielli/.local/lib/python3.8/site-packages (4.12.2)
# Requirement already satisfied: filelock in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (3.7.1)
# Requirement already satisfied: tqdm>=4.27 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: sacremoses in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (0.0.53)
# Requirement already satisfied: packaging>=20.0 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: pyyaml>=5.1 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (1.23.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (0.10.3)
# Requirement already satisfied: requests in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: huggingface-hub>=0.0.17 in /home/novielli/.local/lib/python3.8/site-packages (from transformers) (0.0.19)
# Requirement already satisfied: typing-extensions in /home/novielli/.local/lib/python3.8/site-packages (from huggingface-hub>=0.0.17->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/novielli/.local/lib/python3.8/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/novielli/.local/lib/python3.8/site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/novielli/.local/lib/python3.8/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/novielli/.local/lib/python3.8/site-packages (from requests->transformers) (1.26.10)
# Requirement already satisfied: joblib in /home/novielli/.local/lib/python3.8/site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /home/novielli/.local/lib/python3.8/site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: six in /home/novielli/.local/lib/python3.8/site-packages (from sacremoses->transformers) (1.16.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in /home/novielli/.local/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/novielli/.local/lib/python3.8/site-packages (from imblearn) (0.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/novielli/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.23.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /home/novielli/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/novielli/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.8.1)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/novielli/.local/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/novielli/.local/lib/python3.8/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/novielli/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/novielli/.local/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/novielli/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /home/novielli/.local/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/novielli/.local/lib/python3.8/site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/novielli/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/novielli/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.23.1)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/novielli/.local/lib/python3.8/site-packages (1.23.1)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/novielli/.local/lib/python3.8/site-packages (2.9.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.8.1+cu111 in /home/novielli/.local/lib/python3.8/site-packages (1.8.1+cu111)
# Requirement already satisfied: torchvision==0.9.1+cu111 in /home/novielli/.local/lib/python3.8/site-packages (0.9.1+cu111)
# Requirement already satisfied: torchaudio==0.8.1 in /home/novielli/.local/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: numpy in /home/novielli/.local/lib/python3.8/site-packages (from torch==1.8.1+cu111) (1.23.1)
# Requirement already satisfied: typing-extensions in /home/novielli/.local/lib/python3.8/site-packages (from torch==1.8.1+cu111) (4.3.0)
# Requirement already satisfied: pillow>=4.1.1 in /home/novielli/.local/lib/python3.8/site-packages (from torchvision==0.9.1+cu111) (9.2.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textattack in /home/novielli/.local/lib/python3.8/site-packages (0.3.5)
# Requirement already satisfied: flair in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.11.3)
# Requirement already satisfied: datasets==1.15 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.15.0)
# Requirement already satisfied: pinyin==0.4.0 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.4.0)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.8.1+cu111)
# Requirement already satisfied: filelock in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (3.7.1)
# Requirement already satisfied: terminaltables in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (3.1.10)
# Requirement already satisfied: OpenHowNet in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (2.0)
# Requirement already satisfied: num2words in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.5.10)
# Requirement already satisfied: pandas>=1.0.1 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.4.3)
# Requirement already satisfied: bert-score>=0.3.5 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.3.11)
# Requirement already satisfied: scipy>=1.4.1 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.8.1)
# Requirement already satisfied: tqdm in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (4.64.0)
# Requirement already satisfied: more-itertools in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (8.13.0)
# Requirement already satisfied: word2number in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.1)
# Requirement already satisfied: jieba in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.42.1)
# Requirement already satisfied: language-tool-python in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (2.7.1)
# Requirement already satisfied: click<8.1.0 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (8.0.4)
# Requirement already satisfied: lru-dict in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.1.8)
# Requirement already satisfied: nltk in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (3.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.7.1)
# Requirement already satisfied: pycld2 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.41)
# Requirement already satisfied: editdistance in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.6.0)
# Requirement already satisfied: transformers>=3.3.0 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (4.12.2)
# Requirement already satisfied: numpy>=1.19.2 in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (1.23.1)
# Requirement already satisfied: lemminflect in /home/novielli/.local/lib/python3.8/site-packages (from textattack) (0.2.2)
# Requirement already satisfied: xxhash in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (2.28.1)
# Requirement already satisfied: multiprocess in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (0.70.13)
# Requirement already satisfied: aiohttp in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (3.8.1)
# Requirement already satisfied: huggingface-hub<0.1.0,>=0.0.19 in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (0.0.19)
# Requirement already satisfied: dill in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (0.3.5.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (2022.5.0)
# Requirement already satisfied: packaging in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (21.3)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from datasets==1.15->textattack) (8.0.0)
# Requirement already satisfied: matplotlib in /home/novielli/.local/lib/python3.8/site-packages (from bert-score>=0.3.5->textattack) (3.5.2)
# Requirement already satisfied: pytz>=2020.1 in /home/novielli/.local/lib/python3.8/site-packages (from pandas>=1.0.1->textattack) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/novielli/.local/lib/python3.8/site-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: typing-extensions in /home/novielli/.local/lib/python3.8/site-packages (from torch!=1.8,>=1.7.0->textattack) (4.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/novielli/.local/lib/python3.8/site-packages (from transformers>=3.3.0->textattack) (2022.7.9)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/novielli/.local/lib/python3.8/site-packages (from transformers>=3.3.0->textattack) (0.10.3)
# Requirement already satisfied: sacremoses in /home/novielli/.local/lib/python3.8/site-packages (from transformers>=3.3.0->textattack) (0.0.53)
# Requirement already satisfied: pyyaml>=5.1 in /home/novielli/.local/lib/python3.8/site-packages (from transformers>=3.3.0->textattack) (6.0)
# Requirement already satisfied: gensim>=3.4.0 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (4.2.0)
# Requirement already satisfied: lxml in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (4.9.1)
# Requirement already satisfied: wikipedia-api in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.5.4)
# Requirement already satisfied: tabulate in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.8.10)
# Requirement already satisfied: ftfy in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (6.1.1)
# Requirement already satisfied: deprecated>=1.2.4 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (1.2.13)
# Requirement already satisfied: sentencepiece==0.1.95 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.1.95)
# Requirement already satisfied: hyperopt>=0.2.7 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.2.7)
# Requirement already satisfied: bpemb>=0.3.2 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.3.3)
# Requirement already satisfied: pptree in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (3.1)
# Requirement already satisfied: janome in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.4.2)
# Requirement already satisfied: segtok>=1.5.7 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (1.5.11)
# Requirement already satisfied: sqlitedict>=1.6.0 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (2.0.0)
# Requirement already satisfied: konoha<5.0.0,>=4.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (4.6.5)
# Requirement already satisfied: gdown==4.4.0 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (4.4.0)
# Requirement already satisfied: conllu>=4.0 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (4.5.1)
# Requirement already satisfied: mpld3==0.3 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (0.3)
# Requirement already satisfied: langdetect in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (1.0.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/novielli/.local/lib/python3.8/site-packages (from flair->textattack) (1.1.1)
# Requirement already satisfied: six in /home/novielli/.local/lib/python3.8/site-packages (from gdown==4.4.0->flair->textattack) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /home/novielli/.local/lib/python3.8/site-packages (from gdown==4.4.0->flair->textattack) (4.11.1)
# Requirement already satisfied: joblib in /home/novielli/.local/lib/python3.8/site-packages (from nltk->textattack) (1.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/novielli/.local/lib/python3.8/site-packages (from num2words->textattack) (0.6.2)
# Requirement already satisfied: setuptools in /home/novielli/.local/lib/python3.8/site-packages (from OpenHowNet->textattack) (63.2.0)
# Requirement already satisfied: anytree in /home/novielli/.local/lib/python3.8/site-packages (from OpenHowNet->textattack) (2.8.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/novielli/.local/lib/python3.8/site-packages (from deprecated>=1.2.4->flair->textattack) (1.14.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/novielli/.local/lib/python3.8/site-packages (from gensim>=3.4.0->flair->textattack) (6.0.0)
# Requirement already satisfied: networkx>=2.2 in /home/novielli/.local/lib/python3.8/site-packages (from hyperopt>=0.2.7->flair->textattack) (2.8.4)
# Requirement already satisfied: py4j in /home/novielli/.local/lib/python3.8/site-packages (from hyperopt>=0.2.7->flair->textattack) (0.10.9.5)
# Requirement already satisfied: future in /home/novielli/.local/lib/python3.8/site-packages (from hyperopt>=0.2.7->flair->textattack) (0.18.2)
# Requirement already satisfied: cloudpickle in /home/novielli/.local/lib/python3.8/site-packages (from hyperopt>=0.2.7->flair->textattack) (2.1.0)
# Requirement already satisfied: overrides<4.0.0,>=3.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from konoha<5.0.0,>=4.0.0->flair->textattack) (3.1.0)
# Requirement already satisfied: importlib-metadata<4.0.0,>=3.7.0 in /home/novielli/.local/lib/python3.8/site-packages (from konoha<5.0.0,>=4.0.0->flair->textattack) (3.10.1)
# Requirement already satisfied: cycler>=0.10 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/novielli/.local/lib/python3.8/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (9.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/novielli/.local/lib/python3.8/site-packages (from requests>=2.19.0->datasets==1.15->textattack) (1.26.10)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets==1.15->textattack) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/novielli/.local/lib/python3.8/site-packages (from requests>=2.19.0->datasets==1.15->textattack) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/novielli/.local/lib/python3.8/site-packages (from requests>=2.19.0->datasets==1.15->textattack) (2.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from scikit-learn>=0.21.3->flair->textattack) (3.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/novielli/.local/lib/python3.8/site-packages (from aiohttp->datasets==1.15->textattack) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/novielli/.local/lib/python3.8/site-packages (from aiohttp->datasets==1.15->textattack) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/novielli/.local/lib/python3.8/site-packages (from aiohttp->datasets==1.15->textattack) (1.3.0)
# ...
# Requirement already satisfied: zipp>=3.1.0 in /home/novielli/.local/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.4.2) (3.8.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.6.6)
# Requirement already satisfied: defusedxml in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.1.1)
# Requirement already satisfied: bleach in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (5.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (4.11.1)
# Requirement already satisfied: tinycss2 in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/novielli/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.5.0)
# Requirement already satisfied: six>=1.5 in /home/novielli/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.4.2) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/novielli/.local/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/novielli/.local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/novielli/.local/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/novielli/.local/lib/python3.8/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.1)
# Requirement already satisfied: pycparser in /home/novielli/.local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.21)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlflow in /home/novielli/.local/lib/python3.8/site-packages (1.29.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<5,>=3.7.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (0.4.2)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (3.1.27)
# Requirement already satisfied: gunicorn<21 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (20.1.0)
# Requirement already satisfied: docker<7,>=4.0.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (6.0.0)
# Requirement already satisfied: querystring-parser<2 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (3.19.4)
# Requirement already satisfied: packaging<22 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (21.3)
# Requirement already satisfied: pandas<2 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (1.4.3)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (1.4.41)
# Requirement already satisfied: entrypoints<1 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (0.4)
# Requirement already satisfied: prometheus-flask-exporter<1 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (0.20.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (6.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (2.28.1)
# Requirement already satisfied: scipy<2 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (1.8.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (0.17.3)
# Requirement already satisfied: cloudpickle<3 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (2.1.0)
# Requirement already satisfied: Flask<3 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pytz<2023 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (2022.1)
# Requirement already satisfied: alembic<2 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (1.8.1)
# Requirement already satisfied: click<9,>=7.0 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: numpy<2 in /home/novielli/.local/lib/python3.8/site-packages (from mlflow) (1.23.1)
# Requirement already satisfied: Mako in /home/novielli/.local/lib/python3.8/site-packages (from alembic<2->mlflow) (1.2.2)
# Requirement already satisfied: importlib-resources in /home/novielli/.local/lib/python3.8/site-packages (from alembic<2->mlflow) (5.8.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/novielli/.local/lib/python3.8/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.10)
# Requirement already satisfied: oauthlib>=3.1.0 in /home/novielli/.local/lib/python3.8/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /home/novielli/.local/lib/python3.8/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.5.0)
# Requirement already satisfied: six>=1.10.0 in /home/novielli/.local/lib/python3.8/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/novielli/.local/lib/python3.8/site-packages (from docker<7,>=4.0.0->mlflow) (1.4.1)
# Requirement already satisfied: urllib3>=1.26.0 in /home/novielli/.local/lib/python3.8/site-packages (from docker<7,>=4.0.0->mlflow) (1.26.10)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/novielli/.local/lib/python3.8/site-packages (from Flask<3->mlflow) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/novielli/.local/lib/python3.8/site-packages (from Flask<3->mlflow) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /home/novielli/.local/lib/python3.8/site-packages (from Flask<3->mlflow) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/novielli/.local/lib/python3.8/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.9)
# Requirement already satisfied: setuptools>=3.0 in /home/novielli/.local/lib/python3.8/site-packages (from gunicorn<21->mlflow) (63.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/novielli/.local/lib/python3.8/site-packages (from importlib-metadata!=4.7.0,<5,>=3.7.0->mlflow) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/novielli/.local/lib/python3.8/site-packages (from packaging<22->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/novielli/.local/lib/python3.8/site-packages (from pandas<2->mlflow) (2.8.2)
# Requirement already satisfied: prometheus-client in /home/novielli/.local/lib/python3.8/site-packages (from prometheus-flask-exporter<1->mlflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/novielli/.local/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/novielli/.local/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.17.3->mlflow) (2.6)
# Requirement already satisfied: greenlet!=0.4.17 in /home/novielli/.local/lib/python3.8/site-packages (from sqlalchemy<2,>=1.4.0->mlflow) (1.1.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/novielli/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/novielli/.local/lib/python3.8/site-packages (from Jinja2>=3.0->Flask<3->mlflow) (2.1.1)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1752, in print
#     extend(render(renderable, render_options))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1390, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/segment.py", line 245, in split_lines
#     for segment in segments:
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/console.py", line 1368, in render
#     renderable = rich_cast(renderable)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/rich/protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 130, in __rich__
#     pip_cmd = get_best_invocation_for_this_pip()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/entrypoints.py", line 58, in get_best_invocation_for_this_pip
#     if found_executable and os.path.samefile(
#   File "/usr/lib/python3.8/genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/pip'
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/pip/__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     self.handle_pip_version_check(options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 148, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/self_outdated_check.py", line 237, in pip_self_version_check
#     logger.info("[present-rich] %s", upgrade_prompt)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1577, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1587, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1649, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 950, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.1.2', new='22.2.2'),)
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
import os
import time
import numpy as np
import pandas as pd
import sklearn.metrics
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons
import re
from _datetime import datetime as dt
import random
import torch
from tqdm import tqdm
import transformers
from transformers import AutoModel, AutoTokenizer, AutoConfig, AutoModelForSequenceClassification
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    get_linear_schedule_with_warmup
)
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler, TensorDataset
import datetime
from sklearn.metrics import classification_report, f1_score
from imblearn.under_sampling import RandomUnderSampler
import json
import mlflow

# %%
text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['url', 'email', 'percent', 'money', 'phone', 'user',
        'time', 'url', 'date', 'number'],
    # terms that will be annotated
    annotate={"hashtag", "allcaps", "elongated", "repeated",
        'emphasis', 'censored'},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)

img_1 = re.compile('!\[(.*)\]\(.*\)')
link_1 = re.compile('\[(.*)\]\(.*\)')
link_2 = re.compile('\[(.*)\]: [^\s]+')
code_1 = re.compile('(:?`[^`]+`|```[^`]*```)')

def preprocess(row):
  doc = ""
  doc += str(row.issue_title)
  doc += " "
  doc += str(row.issue_body)
  
  return clean_text(doc)

def clean_text(text):
  cleaned = re.sub(img_1, r'\1 <img>', text)
  cleaned = re.sub(link_1, r'\1 <url>', cleaned)
  cleaned = re.sub(link_2, r'\1 <url>', cleaned)
  cleaned = re.sub(code_1, '<code>', cleaned)
  ekph_cleaned = " ".join(text_processor.pre_process_doc(cleaned))
  return ekph_cleaned
# Out:
# /home/novielli/.local/lib/python3.8/site-packages/ekphrasis/classes/tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# /home/novielli/.local/lib/python3.8/site-packages/ekphrasis/classes/exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
def preprocess_rows(df, label_encoder):
    df = df.fillna({
                        'issue_title': '',
                        'issue_body':''                  
                   })
    df['text'] = df['issue_title'] + ' ' + df['issue_body']
    df['label'] = label_encoder.transform(df['issue_label'])
    df = df.filter(['text', 'label'])
    df['text'] = [clean_text(text) for text in tqdm(df['text'])]
    return df

# %%
def classification_report_to_dataframe(str_representation_of_report):
    split_string = [x.split(' ') for x in str_representation_of_report.split('\n')]
    column_names = ['']+[x for x in split_string[0] if x!='']
    values = []
    for table_row in split_string[1:-1]:
        table_row = [value for value in table_row if value!='']
        if table_row!=[]:
            values.append(table_row)
    for i in values:
        for j in range(len(i)):
            if i[1] == 'avg':
                i[0:2] = [' '.join(i[0:2])]
            if len(i) == 3:
                i.insert(1,np.nan)
                i.insert(2, np.nan)
            else:
                pass
    report_to_df = pd.DataFrame(data=values, columns=column_names)
    return report_to_df

# %%
# !curl -LJO "https://zenodo.org/record/7777793/files/github-labels-top3-803k-train-filtered-urls.csv"
# !curl -LJO "https://zenodo.org/record/7777793/files/github-labels-top3-803k-test-filtered-urls.csv"

# %%
if not os.path.isfile("github-labels-top3-803k-train.csv"):
  # !curl "https://tickettagger.blob.core.windows.net/datasets/github-labels-top3-803k-train.tar.gz" | tar -xz
if not os.path.isfile("github-labels-top3-803k-test.csv"):
  # !curl "https://tickettagger.blob.core.windows.net/datasets/github-labels-top3-803k-test.tar.gz" | tar -xz

# %%
trainset = pd.read_csv("github-labels-top3-803k-train.csv")
testset = pd.read_csv("github-labels-top3-803k-test.csv")

# %%
trainset_filtered_urls = pd.read_csv("github-labels-top3-803k-train-filtered-urls.csv")
testset_filtered_urls = pd.read_csv("github-labels-top3-803k-test-filtered-urls.csv")

# %%
trainset.drop_duplicates(subset=['issue_url'], inplace=True)
testset.drop_duplicates(subset=['issue_url'], inplace=True)
trainset_filtered_urls.drop_duplicates(inplace=True)
testset_filtered_urls.drop_duplicates(inplace=True)
# Out:
#         Unnamed: 0                                          issue_url  \
# 0                0  https://api.github.com/repos/eamodio/vscode-gi...
# 1                1  https://api.github.com/repos/binwiederhier/pco...
# 2                2  https://api.github.com/repos/binwiederhier/pco...
# 3                3  https://api.github.com/repos/Sothatsit/RoyalUr...
# 4                5  https://api.github.com/repos/jankuss/shroom/is...
# ...            ...                                                ...
# 593957      803411  https://api.github.com/repos/uioz/mfe-proxy-se...
# 593958      803412  https://api.github.com/repos/stanleyowen/todo-...
# 593959      803413  https://api.github.com/repos/ryankscott/finish...
# 593960      803414  https://api.github.com/repos/ryankscott/finish...
# 593961      803416  https://api.github.com/repos/OpenRefine/OpenRe...
#
#         issue_label      issue_created_at issue_author_association  \
# 0               bug  2021-01-02T18:07:30Z                     NONE
# 1               bug  2020-12-31T18:19:31Z                    OWNER
# 2               bug  2021-01-03T04:33:36Z                    OWNER
# 3       enhancement  2020-12-25T00:46:00Z                    OWNER
# 4       enhancement  2020-12-31T13:43:33Z                     NONE
# ...             ...                   ...                      ...
# 593957          bug  2021-04-22T03:36:21Z                    OWNER
# 593958          bug  2021-04-18T10:39:38Z                    OWNER
# 593959          bug  2020-06-09T08:06:59Z                    OWNER
# 593960  enhancement  2020-07-17T07:39:00Z                    OWNER
# 593961          bug  2021-04-18T18:08:40Z                     NONE
#
#                                            repository_url  \
# 0       https://api.github.com/repos/eamodio/vscode-gi...
# 1        https://api.github.com/repos/binwiederhier/pcopy
# 2        https://api.github.com/repos/binwiederhier/pcopy
# 3       https://api.github.com/repos/Sothatsit/RoyalUr...
# 4             https://api.github.com/repos/jankuss/shroom
# ...                                                   ...
# 593957  https://api.github.com/repos/uioz/mfe-proxy-se...
# 593958  https://api.github.com/repos/stanleyowen/todo-...
# 593959  https://api.github.com/repos/ryankscott/finish-em
# 593960  https://api.github.com/repos/ryankscott/finish-em
# 593961  https://api.github.com/repos/OpenRefine/OpenRe...
#
#                                               issue_title  \
# 0       Welcome screen on every editor window is very ...
# 1       "pcopy invite" and "pcopy paste abc:" does not...
# 2       UI: Modal overlay is half transparent, shouldn...
# 3       Make the loading screen scale with browser win...
# 4           Single Shroom instance for multiple canvases?
# ...                                                   ...
# 593957                                使用全新的 manifest 文件格式
# 593958                            Inconsistence Dark Mode
# 593959  Update the lastUpdatedAt timestamp in a parent...
# 593960                     Create an Audit Log like thing
# 593961  Windows10 cannot find or load com.google.refin...
#
#                                                issue_body  \
# 0       I just discovered Gitlens and find the functio...
# 1                                                     NaN
# 2                                                     NaN
# 3       Currently the loading wheel is a fixed size in...
# 4       Is it possible to be able to create a single S...
# ...                                                   ...
# 593957     https://github.com/uioz/mfe-proxy-cli/issues/5
# 593958  **Describe the bug**\r\nOne reason dark mode i...
# 593959                          Makes more sense this way
# 593960                 Show what happened and maybe undo?
# 593961  > refine.bat\r\nUsing refine.ini for configura...
#
#                                      issue_slug
# 0            eamodio/vscode-gitlens/issues/1302
# 1                  binwiederhier/pcopy/issues/9
# 2                 binwiederhier/pcopy/issues/16
# 3             Sothatsit/RoyalUrClient/issues/41
# 4                      jankuss/shroom/issues/55
# ...                                         ...
# 593957          uioz/mfe-proxy-server/issues/11
# 593958  stanleyowen/todo-application/issues/111
# 593959          ryankscott/finish-em/issues/165
# 593960          ryankscott/finish-em/issues/220
# 593961        OpenRefine/OpenRefine/issues/3828
#
# [593962 rows x 9 columns]

# %%
train_df = pd.merge(trainset_filtered_urls, trainset, on=['issue_url'], how='inner')
test_df = pd.merge(trainset_filtered_urls, testset, on=['issue_url'], how='inner')

# %%
seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
lenc = LabelEncoder()
lenc.fit(trainset["issue_label"])
# Out:
# LabelEncoder()

# %%
train_size = train_df.groupby("issue_label").size()

# %%
train_set = preprocess_rows(train_df, lenc)
test_set = preprocess_rows(test_df, lenc)
# Out:
# 100%|██████████| 581135/581135 [19:15<00:00, 502.71it/s]
# 100%|██████████| 65951/65951 [01:37<00:00, 677.93it/s]

# %%
seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

print('Using seed: {}'.format(seed_val))
# Out:
# Using seed: 42

# %%
label_encoder = LabelEncoder()
label_encoder.fit(trainset['issue_label'])
# Out:
# LabelEncoder()

# %%
from datasets import Dataset
train_set = Dataset.from_pandas(train_set)
test_set = Dataset.from_pandas(test_set)

# %%
BERT_MODEL = 'roberta-base'
NUM_LABELS = 3

# %%
tokenizer = AutoTokenizer.from_pretrained(BERT_MODEL, model_max_length=128)

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"], padding='max_length', truncation=True)

# %%
tokenized_dataset_train = train_set.map(tokenize_function, batched=True)
tokenized_dataset_test = test_set.map(tokenize_function, batched=True)
# Out:
# Parameter 'function'=<function tokenize_function at 0x7f4dd03f0b80> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/582 [00:00<?, ?ba/s]
#   0%|          | 0/66 [00:00<?, ?ba/s]

# %%
LEARNING_RATE = 2e-5
WEIGHT_DECAY= 1e-8
NUM_TRAIN_EPOCHS = 4
PER_DEVICE_TRAIN_BATCH_SIZE = 32

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TrainingArguments

model = AutoModelForSequenceClassification.from_pretrained(BERT_MODEL, num_labels=NUM_LABELS, 
                                                           max_length=128)



training_args = TrainingArguments(output_dir="test_trainer",
                                 learning_rate=LEARNING_RATE,
                                 weight_decay=WEIGHT_DECAY,
                                 num_train_epochs=NUM_TRAIN_EPOCHS,
                                 per_device_train_batch_size=PER_DEVICE_TRAIN_BATCH_SIZE,
                                 seed = seed_val)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset_train,
)

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, text.
# ***** Running training *****
#   Num examples = 581135
#   Num Epochs = 4
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 72644
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#     <div>
#
#       <progress value='6765' max='72644' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6765/72644 09:45 < 1:35:06, 11.54 it/s, Epoch 0.37/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.528400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.457800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.443300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.426200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.428600</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.434300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.424900</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.418600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.419200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.407200</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.414500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.404500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.410600</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test_trainer/checkpoint-500
# Configuration saved in test_trainer/checkpoint-500/config.json
# Model weights saved in test_trainer/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-1000
# Configuration saved in test_trainer/checkpoint-1000/config.json
# Model weights saved in test_trainer/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-1500
# Configuration saved in test_trainer/checkpoint-1500/config.json
# Model weights saved in test_trainer/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-2000
# Configuration saved in test_trainer/checkpoint-2000/config.json
# Model weights saved in test_trainer/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-2500
# Configuration saved in test_trainer/checkpoint-2500/config.json
# Model weights saved in test_trainer/checkpoint-2500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-3000
# Configuration saved in test_trainer/checkpoint-3000/config.json
# Model weights saved in test_trainer/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-3500
# Configuration saved in test_trainer/checkpoint-3500/config.json
# Model weights saved in test_trainer/checkpoint-3500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-4000
# Configuration saved in test_trainer/checkpoint-4000/config.json
# Model weights saved in test_trainer/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-4500
# Configuration saved in test_trainer/checkpoint-4500/config.json
# Model weights saved in test_trainer/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-5000
# Configuration saved in test_trainer/checkpoint-5000/config.json
# Model weights saved in test_trainer/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-5500
# Configuration saved in test_trainer/checkpoint-5500/config.json
# Model weights saved in test_trainer/checkpoint-5500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-6000
# Configuration saved in test_trainer/checkpoint-6000/config.json
# Model weights saved in test_trainer/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-6500
# Configuration saved in test_trainer/checkpoint-6500/config.json
# Model weights saved in test_trainer/checkpoint-6500/pytorch_model.bin

# %%
output = trainer.predict(tokenized_dataset_test)

# %%
preds = np.argmax(output.predictions, axis=-1)

# %%
print(classification_report(output.label_ids, preds, digits=4))

# %%
cf = classification_report(output.label_ids, preds, digits=4, output_dict=True)

# %%
cf

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(output.label_ids, preds)
cm

# %%
mlflow.end_run()
experiment_name = "no-multi-labels"
try:
    experiment_id = mlflow.create_experiment(experiment_name)
except:
    current_experiment=dict(mlflow.get_experiment_by_name(experiment_name))
    experiment_id=current_experiment['experiment_id']

run_name = "no-multi-labels"

with mlflow.start_run(experiment_id=experiment_id, run_name=run_name):
    mlflow.log_param("model_name", BERT_MODEL)
    mlflow.log_param("lr", LEARNING_RATE)
    mlflow.log_param("weight_decay", WEIGHT_DECAY)
    mlflow.log_param("num_train_epochs", NUM_TRAIN_EPOCHS)
    mlflow.log_param("per_device_train_batch_size", PER_DEVICE_TRAIN_BATCH_SIZE)
    mlflow.log_param("train_bug", train_size['bug'])
    mlflow.log_param("train_enhancement", train_size['enhancement'])
    mlflow.log_param("train_question", train_size['question'])
    mlflow.log_param("test_bug", testset.groupby('issue_label').size()['bug'])
    mlflow.log_param("test_enhancement", testset.groupby('issue_label').size()['enhancement'])
    mlflow.log_param("test_question", testset.groupby('issue_label').size()['question'])
    mlflow.log_metric("no_issues", len(train_set))
    mlflow.log_metric("bug.prec", cf['0']['precision'])
    mlflow.log_metric("bug.rec", cf['0']['recall'])
    mlflow.log_metric("bug.f1", cf['0']['f1-score'])
    mlflow.log_metric("bug.supp", cf['0']['support'])
    mlflow.log_metric("enhancement.prec", cf['1']['precision'])
    mlflow.log_metric("enhancement.rec", cf['1']['recall'])
    mlflow.log_metric("enhancement.f1", cf['1']['f1-score'])
    mlflow.log_metric("enhancement.supp", cf['1']['support'])
    mlflow.log_metric("question.prec", cf['2']['precision'])
    mlflow.log_metric("question.rec", cf['2']['recall'])
    mlflow.log_metric("question.f1", cf['2']['f1-score'])
    mlflow.log_metric("question.supp", cf['2']['support'])
    mlflow.log_metric("f1-micro", cf['accuracy'])
    mlflow.log_metric("prec-macro", cf['macro avg']['precision'])
    mlflow.log_metric("rec-macro", cf['macro avg']['recall'])
    mlflow.log_metric("f1-macro", cf['macro avg']['f1-score'])
    mlflow.log_metric("supp", cf['macro avg']['support'])
    mlflow.log_metric("cm_0_0", cm[0][0])
    mlflow.log_metric("cm_0_1", cm[0][1])
    mlflow.log_metric("cm_0_2", cm[0][2])
    mlflow.log_metric("cm_1_0", cm[1][0])
    mlflow.log_metric("cm_1_1", cm[1][1])
    mlflow.log_metric("cm_1_2", cm[1][2])
    mlflow.log_metric("cm_2_0", cm[2][0])
    mlflow.log_metric("cm_2_1", cm[2][1])
    mlflow.log_metric("cm_2_2", cm[2][2])
mlflow.end_run()

# %%
import pandas as pd
